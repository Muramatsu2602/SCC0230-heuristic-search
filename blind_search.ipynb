# %% [markdown]
# ## Read CSV

# %%
import numpy as np
import pandas as pd
import heapq

# %%
df = pd.read_csv('us_routes_dist.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 airline airline_id source  source_id dest  dest_id codeshare  \
# 0         172      2O        146    ADQ       3531  KLN     7162       NaN
# 1         177      2O        146    KLN       7162  KYK     7161       NaN
# 2         260      3E      10739    BRL       5726  ORD     3830       NaN
# 3         261      3E      10739    BRL       5726  STL     3678       NaN
# 4         262      3E      10739    DEC       4042  ORD     3830       NaN
#
#    stops equipment   distance     from_to
# 0      0       BNI   2.128521  ADQ_KLN_2O
# 1      0       BNI   0.603091  KLN_KYK_2O
# 2      0       CNC   1.153044  BRL_ORD_3E
# 3      0       CNC   1.609324  BRL_STL_3E
# 4      0       CNC  11.138693  DEC_ORD_3E

# %% [markdown]
# ## Create a graph

# %%
# Get uniques source-dest pairs from df
graph = df[['source', 'dest', 'distance']]

# %%
# Drop from graph where distance is NaN
graph = graph.dropna()
graph
# Out:
#      source dest   distance
# 0       ADQ  KLN   2.128521
# 1       KLN  KYK   0.603091
# 2       BRL  ORD   1.153044
# 3       BRL  STL   1.609324
# 4       DEC  ORD  11.138693
# ...     ...  ...        ...
# 2189    TUS  ATL   4.136367
# 2190    TYS  ATL  34.461664
# 2191    VLD  ATL  10.263855
# 2192    VPS  ATL   6.441787
# 2193    XNA  ATL  11.844883
#
# [2194 rows x 3 columns]

# %%
graph.loc[graph['source'] == 'ADQ']
# Out:
#     source dest   distance
# 0      ADQ  KLN   2.128521
# 99     ADQ  ANC   1.587634
# 280    ADQ  AKK  16.320888

# %%
graph.loc[(graph['source'] == 'ORD') & (graph['dest'] == 'ATL')]
print(graph.loc[(graph['source'] == 'ORD')])

print(graph.loc[graph['source'] == 'BRL'])

graph.loc[(graph['source'] == 'ORD')&((graph['dest'] == 'STL'))]
# Out:
#      source dest   distance
# 7       ORD  BRL   0.546768
# 8       ORD  DEC   0.305825
# 1390    ORD  ABQ   9.037408
# 1391    ORD  ALO   9.037408
# 1392    ORD  ART   0.842480
# ...     ...  ...        ...
# 1485    ORD  TVC  11.140467
# 1486    ORD  TYS  32.384502
# 1487    ORD  XNA  36.401936
# 1908    ORD  MSY   4.778303
# 2152    ORD  ATL  40.090622
#
# [102 rows x 3 columns]
#   source dest  distance
# 2    BRL  ORD  1.153044
# 3    BRL  STL  1.609324
#      source dest   distance
# 1478    ORD  STL  17.124137

# %%
graph_dict = {}

for row in df.itertuples():
    source = row.source
    dest = row.dest
    distance = row.distance
    
    if pd.isna(distance):
        continue

    if source not in graph_dict:
        graph_dict[source] = []
    
    graph_dict[source].append((dest, distance))

# %%
graph_dict
# Out:
# {'ADQ': [('KLN', 2.128521013470194),
#   ('ANC', 1.5876342418321463),
#   ('AKK', 16.32088811385432)],
#  'KLN': [('KYK', 0.6030914575036689)],
#  'BRL': [('ORD', 1.153043939982465), ('STL', 1.6093243966706878)],
#  'DEC': [('ORD', 11.13869269275995), ('STL', 0.6431385370968897)],
#  'JBR': [('STL', 1.3701737432323084)],
#  'ORD': [('BRL', 0.546767573006186),
#   ('DEC', 0.3058249659506772),
#   ('ABQ', 9.037407550588908),
#   ('ALO', 9.037407550588908),
#   ('ART', 0.8424798669239778),
#   ('ATL', 1.550020033026388),
#   ('AUS', 1.2986829487489724),
#   ('AZO', 1.3753358530752666),
#   ('BDL', 1.3753358530752666),
#   ('BMI', 1.221712486613395),
#   ('BNA', 0.394881157749491),
#   ('BOS', 0.5331243710229252),
#   ('BUF', 0.8424798669239778),
#   ('BWI', 0.7128993776051306),
#   ('CHA', 1.550020033026388),
#   ('CHO', 0.4285467870648635),
#   ('CID', 1.221712486613395),
#   ('CLE', 0.5331243710229252),
#   ('CLT', 0.7128993776051306),
#   ('CMH', 1.177191196754432),
#   ('CMI', 8.762743788219026),
#   ('COU', 9.037407550588908),
#   ('CVG', 12.21403119320778),
#   ('CWA', 9.037407550588908),
#   ('DAY', 12.21403119320778),
#   ('DBQ', 4.605223077835672),
#   ('DCA', 9.198401588837754),
#   ('DEN', 14.49980816500657),
#   ('DFW', 12.920459724288584),
#   ('DSM', 13.563934693496495),
#   ('DTW', 14.781281538723068),
#   ('ELP', 8.688765335780523),
#   ('EVV', 4.605223077835672),
#   ('EWR', 27.700905121535097),
#   ('FAR', 18.68411732017117),
#   ('FLL', 16.90399802318908),
#   ('FNT', 21.315386292746062),
#   ('FSD', 13.558187907981806),
#   ('FWA', 38.60798254867175),
#   ('GRB', 17.509534881876228),
#   ('GRR', 5.942250192597125),
#   ('HPN', 10.334550474491648),
#   ('HSV', 21.448798045555552),
#   ('IAH', 28.131549391894996),
#   ('ICT', 13.588219666041212),
#   ('IND', 11.140466742024588),
#   ('JAX', 12.5033312304057),
#   ('JFK', 16.901292022097753),
#   ('LAS', 9.7556363763416),
#   ('LAX', 12.63158992718594),
#   ('LEX', 27.700905121535097),
#   ('LGA', 21.315386292746062),
#   ('LIT', 16.554415039420437),
#   ('LSE', 18.212168257211463),
#   ('MCI', 16.35112351141),
#   ('MCO', 12.578091224746398),
#   ('MDT', 7.375507945406745),
#   ('MEM', 18.1266178385189),
#   ('MHK', 12.88000141131497),
#   ('MIA', 28.53765512776364),
#   ('MKE', 22.88573960912017),
#   ('MLI', 14.983642793512857),
#   ('MQT', 20.15266125271932),
#   ('MSN', 15.316931587162516),
#   ('MSP', 9.198401588837754),
#   ('MSY', 21.448798045555552),
#   ('OKC', 16.454105527660683),
#   ('OMA', 17.12413712131326),
#   ('PBI', 32.384502234197754),
#   ('PDX', 36.01688352441865),
#   ('PHL', 13.933795119728288),
#   ('PHX', 9.611893257176774),
#   ('PIA', 15.757456979443509),
#   ('PIT', 14.260504953939613),
#   ('PSP', 14.49980816500657),
#   ('RDU', 13.558187907981806),
#   ('RIC', 28.131549391894996),
#   ('RNO', 18.212168257211463),
#   ('ROC', 16.454105527660683),
#   ('RST', 17.077373082160587),
#   ('RSW', 36.40193612348762),
#   ('SAN', 39.05640702808821),
#   ('SAT', 14.222979847355877),
#   ('SDF', 15.9895268578373),
#   ('SEA', 2.6251717156118555),
#   ('SFO', 7.705006615608503),
#   ('SGF', 17.694515116119607),
#   ('SJC', 19.744295573845537),
#   ('SLC', 9.427617851026037),
#   ('SNA', 13.588219666041212),
#   ('STL', 17.12413712131326),
#   ('SUX', 20.727215338792075),
#   ('SYR', 23.40372749616778),
#   ('TOL', 14.118297805375784),
#   ('TPA', 15.047630653120049),
#   ('TUL', 14.112542054570543),
#   ('TUS', 38.60798254867175),
#   ('TVC', 11.140466742024588),
#   ('TYS', 32.384502234197754),
#   ('XNA', 36.40193612348762),
#   ('MSY', 4.778302988710313),
#   ('ATL', 40.09062209219371)],
#  'STL': [('BRL', 3.748219914427572),
#   ('DEC', 1.6548359914959958),
#   ('JBR', 2.8732273012232445),
#   ('CGI', 16.454105527660683),
#   ('IRK', 15.900588582116232),
#   ('MWA', 15.9895268578373),
#   ('OWB', 22.90403696257687),
#   ('TBN', 9.899588373257158),
#   ('UIN', 9.35378026325686),
#   ('CLT', 14.573077078791393),
#   ('DCA', 14.34623287143172),
#   ('DFW', 25.128711776662136),
#   ('LAX', 9.518097307015095),
#   ('LGA', 9.9640442201469),
#   ('MIA', 21.07199348658255),
#   ('ORD', 10.966903788129402),
#   ('PHL', 17.412208436287294),
#   ('PHX', 10.334550474491648),
#   ('PIT', 24.161495414127263),
#   ('SEA', 20.494808714820408),
#   ('ATL', 5.762506775086129)],
#  'KTN': [('MTM', 1.8737423413536056),
#   ('JNU', 24.931766974860142),
#   ('SEA', 14.73987663565556)],
#  'MTM': [('KTN', 1.8737423413536056)],
#  'ATL': [('LWB', 2.551195534983341),
#   ('MCN', 2.2667460863460605),
#   ('MEI', 3.785606764308555),
#   ('MSL', 1.7203108353418963),
#   ('PIB', 0.9914618433283297),
#   ('TUP', 2.817332815391097),
#   ('AZO', 9.885451421096532),
#   ('CHA', 8.363821114942326),
#   ('CID', 4.190566371870476),
#   ('CRW', 1.7035059140461422),
#   ('CVG', 7.401832480049363),
#   ('EVV', 2.261977043486501),
#   ('FWA', 4.223566838733543),
#   ('GSO', 3.4257836004336304),
#   ('GSP', 6.814637050042806),
#   ('LAN', 2.466990082945033),
#   ('LEX', 7.15400066712223),
#   ('MBS', 21.448798045555552),
#   ('MSP', 16.554415039420437),
#   ('ROA', 10.331995855963292),
#   ('SYR', 6.462012873337382),
#   ('TYS', 3.1821612702538213),
#   ('XNA', 5.1295237222322125),
#   ('CLT', 12.743837296171836),
#   ('DFW', 11.740673784565452),
#   ('MIA', 8.801254034868638),
#   ('ORD', 9.93558808923862),
#   ('PHL', 14.275361956162593),
#   ('PHX', 6.874692229350543),
#   ('DEN', 12.755888627999711),
#   ('ABE', 10.295740620531424),
#   ('ABQ', 4.056385505891294),
#   ('ABY', 7.503922685256927),
#   ('AEX', 4.983933906910681),
#   ('AGS', 8.715718227065656),
#   ('ALB', 13.188490004551632),
#   ('ATW', 16.553585371310014),
#   ('AUS', 16.621830902184268),
#   ('AVL', 14.8416460255245),
#   ('AVP', 9.4509541090096),
#   ('BDL', 12.432298541586846),
#   ('BHM', 36.331671072508),
#   ('BMI', 40.61580562949908),
#   ('BNA', 20.15266125271932),
#   ('BOS', 44.12518336616964),
#   ('BQK', 1.7160860397500557),
#   ('BTR', 30.70982029727948),
#   ('BTV', 42.55192132871005),
#   ('BUF', 5.225196399708177),
#   ('BWI', 18.424199283144183),
#   ('CAE', 3.655201172428543),
#   ('CAK', 16.324667770609494),
#   ('CHA', 14.092757020492703),
#   ('CHO', 3.0972474365657927),
#   ('CHS', 7.9095608578266),
#   ('CID', 15.85456956316996),
#   ('CLE', 9.772805686524633),
#   ('CLT', 7.890587951319652),
#   ('CMH', 8.816227361788506),
#   ('COS', 6.268198793989289),
#   ('CRW', 1.5548802390890448),
#   ('CSG', 2.7847653191661275),
#   ('CVG', 8.724663453097156),
#   ('DAB', 12.14557114550831),
#   ('DAL', 13.52577045470968),
#   ('DAY', 4.378998684404046),
#   ('DCA', 10.63129819056071),
#   ('DEN', 43.13737090075295),
#   ('DFW', 29.161443339580504),
#   ('DHN', 49.00546516755279),
#   ('DSM', 47.27070154217239),
#   ('DTW', 34.83639065674419),
#   ('ECP', 41.501642844126806),
#   ('ELP', 25.77329287224921),
#   ('EVV', 48.68989795253626),
#   ('EWN', 5.408673827859574),
#   ('EWR', 43.71436790630929),
#   ('EYW', 34.74479488851392),
#   ('FAY', 47.18771465264398),
#   ('FLL', 5.677238897100491),
#   ('FNT', 7.243785145815097),
#   ('FSM', 25.288439451742416),
#   ('FWA', 4.9086182696438),
#   ('GNV', 10.666696677528243),
#   ('GPT', 3.785049017895159),
#   ('GRB', 31.531551437305872),
#   ('GRK', 16.89617589858907),
#   ('GRR', 9.39208275443618),
#   ('GSO', 24.102600755351727),
#   ('GSP', 36.748330822556206),
#   ('GTR', 7.354177888354314),
#   ('HPN', 40.79671796837906),
#   ('HSV', 25.22842902596692),
#   ('IAD', 5.720277940953299),
#   ('IAH', 10.92869927782716),
#   ('ICT', 20.84455188336272),
#   ('ILM', 31.092301673523465),
#   ('IND', 5.860968700551471),
#   ('JAN', 1.818316323626591),
#   ('JAX', 7.982907433299302),
#   ('JFK', 12.715737531917895),
#   ('LAS', 10.067799622711233),
#   ('LAX', 13.332706711250308),
#   ('LEX', 8.871692437064358),
#   ('LFT', 28.446944786988954),
#   ('LGA', 16.6216490030436),
#   ('LIT', 4.063185801551764),
#   ('MCI', 10.28582317723222),
#   ('MCO', 8.490192862629744),
#   ('MDT', 1.988783440624971),
#   ('MDW', 5.155487296634097),
#   ('MEM', 9.260689092158923),
#   ('MGM', 11.852737406170135),
#   ('MHT', 3.3528556100486937),
#   ('MIA', 5.900623138242828),
#   ('MKE', 11.179060495822652),
#   ('MLB', 12.93171282849371),
#   ('MLI', 6.137714228448527),
#   ('MLU', 4.115691588344297),
#   ('MOB', 7.411094311296743),
#   ('MSN', 12.186099162833862),
#   ('MSP', 15.316931587162516),
#   ('MSY', 15.395529820411069),
#   ('MYR', 13.953462559713078),
#   ('OAJ', 1.932564578095044),
#   ('OKC', 3.4961152842676944),
#   ('OMA', 18.749667991179862),
#   ('ORD', 9.856154932759946),
#   ('ORF', 13.92490212400348),
#   ('PBI', 7.687116310191282),
#   ('PDX', 25.058640615493903),
#   ('PHF', 1.6984369841352926),
#   ('PHL', 3.609370093856313),
#   ('PHX', 3.0974788582376345),
#   ('PIA', 1.7232899961993302),
#   ('PIT', 3.108765066055503),
#   ('PNS', 7.592001156613222),
#   ('PVD', 11.274129369048554),
#   ('PWM', 7.302986252766598),
#   ('RDU', 9.649055327032825),
#   ('RIC', 7.317275894382778),
#   ('ROA', 12.651282839119558),
#   ('ROC', 10.786116674734632),
#   ('RSW', 13.40630111959318),
#   ('SAN', 4.349521894860279),
#   ('SAT', 24.21446739960945),
#   ('SAV', 20.92282086459606),
#   ('SBN', 8.569598588970935),
#   ('SDF', 2.708073139668156),
#   ('SEA', 6.544163106245748),
#   ('SFO', 11.50823191106478),
#   ('SGF', 6.36056483299381),
#   ('SHV', 33.98127251293947),
#   ('SLC', 11.50823191106478),
#   ('SMF', 6.36056483299381),
#   ('SNA', 33.98127251293947),
#   ('SRQ', 28.42564949718601),
#   ('STL', 8.86788449411668),
#   ('SYR', 22.225259534999797),
#   ('TLH', 22.225259534999797),
#   ('TPA', 13.681884508816948),
#   ('TRI', 2.3265720572304907),
#   ('TUL', 3.3544147247389464),
#   ('TUS', 16.010783125223476),
#   ('TYS', 4.449253374781415),
#   ('VLD', 3.825324532487287),
#   ('VPS', 5.417407271631167),
#   ('XNA', 12.448765051626063)],
#  'EYW': [('FLL', 3.479722081602122),
#   ('RSW', 2.9186507822715204),
#   ('TPA', 3.1104412669217907),
#   ('MIA', 17.84434031197956),
#   ('ATL', 16.40089113852978)],
#  'FLL': [('EYW', 1.0041711848863706),
#   ('MCO', 2.423815688442152),
#   ('TPA', 0.4443679765996962),
#   ('CLT', 6.479532578420092),
#   ('DCA', 20.137347313738392),
#   ('DFW', 21.301049358772666),
#   ('ORD', 23.68566806207706),
#   ('PHL', 4.618758102948263),
#   ('PHX', 12.263176951797329),
#   ('ATL', 10.536990980640514)],
#  'GLH': [('TUP', 3.358238993004842)],
#  'GNV': [('MCO', 0.8365701278323429),
#   ('TPA', 2.551195534983341),
#   ('CLT', 10.45729976367291),
#   ('MIA', 9.679594271524255),
#   ('ATL', 5.416648531614038)],
#  'JAX': [('TPA', 4.746519669825276),
#   ('CLT', 23.161021162341264),
#   ('DCA', 25.86811691200785),
#   ('DFW', 15.755335679613223),
#   ('MIA', 14.551532862130466),
#   ('ORD', 14.658416521309215),
#   ('PHL', 7.527407332595459),
#   ('ATL', 32.05716830158077)],
#  'LWB': [('ATL', 3.785606764308555)],
#  'MCN': [('ATL', 1.7203108353418963), ('MCO', 2.5570799984497987)],
#  'MCO': [('FLL', 1.6834638493704734),
#   ('GNV', 3.358238993004842),
#   ('MCN', 2.037062106572334),
#   ('PNS', 2.037062106572334),
#   ('RSW', 1.4510692973810653),
#   ('TLH', 7.736160929453272),
#   ('CLT', 2.3769553579608185),
#   ('DCA', 15.975487933157618),
#   ('DFW', 8.86788449411668),
#   ('JFK', 6.703253542503768),
#   ('LAX', 9.898653575737857),
#   ('MIA', 4.819531311503159),
#   ('ORD', 10.696403036610374),
#   ('PHL', 14.275361956162593),
#   ('PHX', 6.874692229350543),
#   ('SAN', 5.499969724414291),
#   ('SEA', 6.919533263957109),
#   ('ATL', 15.053206525396693)],
#  'MEI': [('ATL', 0.8053548494843464)],
#  'MSL': [('ATL', 5.636605528437041)],
#  'PBI': [('TPA', 2.1080719163174546),
#   ('CLT', 15.9895268578373),
#   ('DCA', 8.714047790824406),
#   ('DFW', 14.083540176501574),
#   ('LAX', 12.920459724288584),
#   ('LGA', 16.35112351141),
#   ('ORD', 13.933795119728288),
#   ('PHL', 2.6251717156118555),
#   ('ATL', 5.720277940953299)],
#  'PIB': [('ATL', 7.37074701739931)],
#  'PNS': [('MCO', 10.381005978974011),
#   ('TPA', 5.064786404428452),
#   ('CLT', 14.810592021343489),
#   ('DCA', 5.273805634782164),
#   ('DFW', 5.643493643010762),
#   ('MIA', 28.013107848948493),
#   ('ATL', 4.995681849820553)],
#  'RSW': [('EYW', 3.2164496695317557),
#   ('MCO', 4.532567598929636),
#   ('CLT', 5.98185118668715),
#   ('DCA', 4.512780573145366),
#   ('DFW', 14.875802411663503),
#   ('ORD', 40.70229001516432),
#   ('PHL', 8.926669742831548),
#   ('ATL', 6.06998974440562)],
#  'TLH': [('MCO', 41.70585574364023),
#   ('TPA', 47.03506712925665),
#   ('CLT', 2.9239655730761327),
#   ('DCA', 9.758219830533044),
#   ('DFW', 7.714695699046336),
#   ('MIA', 8.71243051130358),
#   ('ATL', 9.755534905535622)],
#  'TPA': [('EYW', 12.052448195308742),
#   ('FLL', 4.193299576220694),
#   ('GNV', 3.825324532487287),
#   ('JAX', 12.63158992718594),
#   ('PBI', 8.86788449411668),
#   ('PNS', 9.037407550588908),
#   ('TLH', 11.10309643256348),
#   ('CLT', 3.408550007454536),
#   ('DCA', 30.515606961591686),
#   ('DFW', 24.161495414127263),
#   ('JFK', 19.51255373937332),
#   ('MIA', 15.797145132659704),
#   ('ORD', 11.563050143554385),
#   ('PHL', 7.374823259693271),
#   ('PHX', 9.920114026700572),
#   ('ATL', 7.630112545023476)],
#  'TUP': [('ATL', 27.584643009673), ('GLH', 17.463710738697095)],
#  'LAS': [('LAX', 3.959153625522732),
#   ('CLT', 12.26133854304479),
#   ('DCA', 15.699828076994988),
#   ('DFW', 17.64990327381459),
#   ('JFK', 10.74630229828386),
#   ('LAX', 17.672728465840983),
#   ('MIA', 15.55031168193579),
#   ('ORD', 8.640573539768164),
#   ('PHL', 13.893079050150536),
#   ('PHX', 14.810738609516166),
#   ('ATL', 14.1717802039079)],
#  'LAX': [('LAS', 3.902747731582662),
#   ('ABQ', 15.070535734263014),
#   ('ANC', 12.49558409540588),
#   ('AUS', 18.686044755165867),
#   ('BDL', 21.79458832401741),
#   ('BNA', 15.379619151335168),
#   ('BOS', 14.810738609516166),
#   ('CLT', 21.63371637274376),
#   ('CMH', 5.434911791596594),
#   ('DCA', 21.43305357671068),
#   ('DEN', 16.07654246973015),
#   ('DFW', 16.564456912952313),
#   ('ELP', 13.72241483324916),
#   ('EUG', 13.064533663373318),
#   ('FAT', 8.569576036724047),
#   ('HNL', 9.113745270779509),
#   ('IAD', 8.008112245833136),
#   ('IAH', 7.554272305903669),
#   ('IND', 20.846176149378906),
#   ('JFK', 15.070535734263014),
#   ('KOA', 7.780545286344802),
#   ('LAS', 14.40033716047266),
#   ('LIH', 12.49558409540588),
#   ('MCO', 1.4331895306551956),
#   ('MFR', 3.3262051011565354),
#   ('MIA', 0.7732316604896549),
#   ('MMH', 0.4677018548239611),
#   ('MRY', 1.7582586183447912),
#   ('OGG', 0.7999974843993877),
#   ('OKC', 0.8766112794869985),
#   ('ORD', 3.3262051011565354),
#   ('PBI', 0.9887018925350058),
#   ('PDX', 1.3861977294834924),
#   ('PHL', 0.988378841231762),
#   ('PHX', 0.7732316604896549),
#   ('PIT', 3.741322318902506),
#   ('RDM', 1.7582586183447912),
#   ('RDU', 2.62425738017378),
#   ('RNO', 0.6347528211714198),
#   ('SAF', 3.288040044136931),
#   ('SAN', 86.33287713153993),
#   ('SEA', 2.4526376957837632),
#   ('SFO', 45.2456799221936),
#   ('SJC', 41.48152030908404),
#   ('SLC', 1.1077108080434162),
#   ('SMF', 0.8424798669239778),
#   ('STL', 39.2887559772566),
#   ('STS', 1.550020033026388),
#   ('TUS', 47.48173824813617),
#   ('XNA', 42.30124495239022),
#   ('ATL', 18.817658674902876),
#   ('MSP', 9.7556363763416),
#   ('OGG', 24.44820741340849)],
#  'MCG': [('NIB', 16.107975535461073)],
#  'NIB': [('MCG', 1.3503407196803772)],
#  'TLJ': [('MCG', 48.612122815597225)],
#  'AKP': [('FAI', 6.312787352986868),
#   ('BTT', 16.010783125223476),
#   ('FAI', 13.085716382664282)],
#  'BTT': [('AKP', 4.24969601951998),
#   ('AET', 14.059128846798677),
#   ('AKP', 12.34913220458301),
#   ('FAI', 15.516643863212831)],
#  'CEM': [('IRC', 10.669942695317324)],
#  'CIK': [('FAI', 2.255434329859068), ('FYU', 3.451006489479312)],
#  'FAI': [('BTT', 6.91119384472196),
#   ('CEM', 39.66772649794244),
#   ('CIK', 6.939907164342815),
#   ('FYU', 10.195807497771725),
#   ('MLY', 10.97029491267466),
#   ('WBQ', 4.287027342609985),
#   ('ANC', 26.87114159893696),
#   ('FYU', 40.98590101612019),
#   ('GAL', 30.70982029727948),
#   ('RBY', 13.946325554162405),
#   ('SCC', 15.580344485103565),
#   ('AET', 15.969394759585857),
#   ('AKP', 3.266081811181592),
#   ('BTT', 44.59182495321799),
#   ('FYU', 48.14510938952077),
#   ('GAL', 3.277321306678888),
#   ('RBY', 11.75575335653785)],
#  'FYU': [('CIK', 20.249658904616407),
#   ('FAI', 4.752737684029092),
#   ('BTI', 9.593996840860688),
#   ('FAI', 8.060605802050231),
#   ('FAI', 7.967669196791172),
#   ('VEE', 41.00308863346167)],
#  'IRC': [('FAI', 12.08292999056608)],
#  'WBQ': [('FAI', 2.3226857535304872)],
#  'BET': [('EEK', 4.313749471558197),
#   ('KPN', 4.056385505891294),
#   ('KWN', 7.503922685256927),
#   ('KWT', 4.983933906910681),
#   ('MLL', 8.715718227065656),
#   ('NME', 13.188490004551632),
#   ('WNA', 16.553585371310014),
#   ('ANC', 47.67389061982471),
#   ('CYF', 6.416154182805401),
#   ('EEK', 16.118089272227387),
#   ('HPB', 17.39080263879582),
#   ('KKH', 38.73276705254717),
#   ('KLG', 4.197115872300928),
#   ('KUK', 5.240898164783035),
#   ('KWK', 3.5440647099578197),
#   ('KWN', 3.402738916361566),
#   ('KWT', 2.25230725319839),
#   ('MLL', 0.6567975209882793),
#   ('NME', 13.24289562194352),
#   ('OOK', 14.803664869391968),
#   ('VAK', 0.3814203233336968)],
#  'CYF': [('BET', 14.8416460255245),
#   ('BET', 47.17823695834999),
#   ('KPN', 20.15266125271932)],
#  'EEK': [('BET', 9.4509541090096),
#   ('KWN', 12.432298541586846),
#   ('KWN', 42.30124495239022)],
#  'KKH': [('KWK', 36.331671072508),
#   ('BET', 10.982802970912656),
#   ('KWK', 8.098951382226634)],
#  'KPN': [('CYF', 20.15266125271932),
#   ('BET', 12.28692083208134),
#   ('CYF', 13.434080179664871)],
#  'KWK': [('BET', 1.7160860397500557),
#   ('BET', 29.200248070925223),
#   ('KKH', 9.728101101614724),
#   ('KPN', 43.2338536343312)],
#  'KWN': [('BET', 36.1382431682215),
#   ('EEK', 37.54643523903867),
#   ('BET', 27.120433444280664),
#   ('TOG', 14.196399417238158)],
#  'NME': [('OOK', 42.55192132871005), ('OOK', 3.3986265491165657)],
#  'PKA': [('BET', 8.060605802050231)],
#  'PTU': [('BET', 3.655201172428543)],
#  'WNA': [('PKA', 14.092757020492703)],
#  'ABL': [('OTZ', 28.53765512776364),
#   ('SHG', 39.38956602950423),
#   ('OTZ', 15.969394759585857),
#   ('SHG', 12.86419312235494)],
#  'AIN': [('ATK', 9.271167163425236), ('BRW', 5.456180135460071)],
#  'ANC': [('ADQ', 12.376997014387502),
#   ('ANI', 12.582660599715012),
#   ('BET', 3.2262422128138186),
#   ('CDV', 8.609965879882916),
#   ('ENA', 7.8764286710531),
#   ('FAI', 41.88322790132629),
#   ('HOM', 12.568738418788982),
#   ('KSM', 34.88052307286848),
#   ('UNK', 16.118089272227387),
#   ('VDZ', 3.5440647099578197),
#   ('LAX', 9.53371666651644),
#   ('PHX', 7.867989994439234)],
#  'ANI': [('ANC', 13.24289562194352),
#   ('HCR', 6.715067677283321),
#   ('KLG', 13.946325554162405),
#   ('RSH', 11.498171780572909),
#   ('SHX', 1.8826166073869637),
#   ('HCR', 15.211462093040064),
#   ('KLG', 16.061005132024437)],
#  'ANV': [('HCR', 7.972819116281153)],
#  'ATK': [('AIN', 11.65449890560672), ('BRW', 6.96646350882195)],
#  'AUK': [('EMK', 7.082964451550877)],
#  'BKC': [('DRG', 1.969226183193212),
#   ('OTZ', 3.3986265491165657),
#   ('DRG', 33.30422003389376),
#   ('OTZ', 26.0745880056735)],
#  'BRW': [('AIN', 6.069434382213256),
#   ('ATK', 39.66772649794244),
#   ('NUI', 5.720611018920805),
#   ('PIZ', 6.715067677283321)],
#  'BTI': [('FYU', 8.346113946361992), ('SCC', 3.0388439102349385)],
#  'CDV': [('ANC', 7.58692836073689)],
#  'DRG': [('BKC', 35.13919740811786),
#   ('OTZ', 4.767954260554806),
#   ('BKC', 3.266081811181592),
#   ('OTZ', 3.882829958916419)],
#  'ELI': [('KKA', 44.12518336616964),
#   ('OME', 1.7160860397500557),
#   ('GLV', 5.461537668492035),
#   ('KKA', 45.042729078997645),
#   ('OME', 9.956593929742604)],
#  'EMK': [('AUK', 43.50016494916359), ('KOT', 36.1382431682215)],
#  'ENA': [('ANC', 6.041449209662597)],
#  'GAL': [('FAI', 29.820550255794533),
#   ('HSL', 3.561522085053865),
#   ('KAL', 11.498171780572909),
#   ('NUL', 13.254784090519278),
#   ('RBY', 9.149307295569264),
#   ('KAL', 3.798089844869328),
#   ('NUL', 2.2891082720134546)],
#  'GAM': [('OME', 8.372360563564316),
#   ('SVA', 12.04782825582029),
#   ('OME', 8.98693876363298),
#   ('SVA', 30.90389351961192)],
#  'GLV': [('OME', 4.2428769584193065),
#   ('WMO', 30.90237488655231),
#   ('ELI', 15.900588582116232),
#   ('WMO', 24.148020084849104)],
#  'HCR': [('ANI', 40.32049198046721),
#   ('ANV', 30.07994385112534),
#   ('ANV', 17.99561732404454)],
#  'HOM': [('ANC', 13.863498491477218)],
#  'HPB': [('SCM', 1.363172817372306), ('VAK', 7.220076687185635)],
#  'HSL': [('GAL', 51.55515063110909),
#   ('KYU', 13.824615508406042),
#   ('HUS', 1.7716568973529916),
#   ('RBY', 5.192404487510915)],
#  'IAN': [('ORV', 11.28052357607205),
#   ('OTZ', 19.61495931812857),
#   ('ORV', 4.048908453407014),
#   ('OTZ', 12.86419312235494)],
#  'KAL': [('GAL', 46.08033654581675),
#   ('NUL', 19.19884687265981),
#   ('HSL', 3.7640690060149287)],
#  'KKA': [('ELI', 3.4448594276378097),
#   ('SKK', 48.612122815597225),
#   ('UNK', 30.890627844643937),
#   ('OME', 41.62360254193453),
#   ('SKK', 45.12881697238158)],
#  'KLG': [('ANI', 10.938045679731756),
#   ('BET', 44.17101199268922),
#   ('RSH', 32.12886001630063),
#   ('RSH', 18.68411732017117)],
#  'KOT': [('EMK', 49.00546516755279), ('KSM', 16.414025455192732)],
#  'KSM': [('ANC', 14.058568833909575),
#   ('KOT', 14.251070870245591),
#   ('MOU', 44.94546894886105)],
#  'KTS': [('TLA', 28.77385781085028),
#   ('WAA', 45.19673941186023),
#   ('OME', 44.89446620728744),
#   ('WAA', 14.345601451840643)],
#  'KVL': [('OTZ', 8.235241700410183), ('OTZ', 19.619038741916142)],
#  'KWT': [('BET', 34.83639065674419)],
#  'KYU': [('GAL', 47.67389061982471), ('FAI', 4.678207349266973)],
#  'MLL': [('RSH', 17.39080263879582)],
#  'MOU': [('KSM', 3.402738916361566)],
#  'MYU': [('BET', 5.246593064894889)],
#  'NUI': [('BRW', 15.580344485103565), ('SCC', 29.820550255794533)],
#  'NUL': [('GAL', 13.254784090519278),
#   ('KAL', 9.83022340785284),
#   ('KYU', 5.319362260347305)],
#  'OBU': [('ABL', 12.2919979691332),
#   ('OTZ', 8.782997673991932),
#   ('ABL', 15.319508457903284),
#   ('OTZ', 49.06929860505152)],
#  'OME': [('ELI', 14.471568525254094),
#   ('GAM', 33.10278963683009),
#   ('GLV', 8.954198183131552),
#   ('KTS', 19.087409228825504),
#   ('SHH', 1.972570744318628),
#   ('SKK', 25.77329287224921),
#   ('SVA', 48.68989795253626),
#   ('TLA', 5.408673827859574),
#   ('UNK', 43.71436790630929),
#   ('WAA', 34.74479488851392),
#   ('WMO', 6.985138981107955),
#   ('ELI', 38.90615961807177),
#   ('GAM', 4.5909178608414924),
#   ('KKA', 6.91119384472196),
#   ('OTZ', 4.615764875883098),
#   ('SHH', 16.202869660873322),
#   ('SVA', 44.12518336616964),
#   ('TLA', 11.294311590357092),
#   ('TNC', 49.00546516755279),
#   ('UNK', 48.68989795253626),
#   ('WMO', 38.19938570390547)],
#  'OOK': [('MYU', 9.83022340785284)],
#  'ORV': [('IAN', 4.021075145568373),
#   ('OTZ', 8.427383324081205),
#   ('IAN', 47.851623936358685),
#   ('OTZ', 15.887842454181843)],
#  'OTZ': [('ABL', 39.406882999229474),
#   ('BKC', 38.40010752401111),
#   ('DRG', 4.9086182696438),
#   ('IAN', 40.450658710058335),
#   ('ORV', 38.228022352193214),
#   ('SHG', 3.0388439102349385),
#   ('WLK', 10.093558402955004),
#   ('WTK', 28.46302131504356),
#   ('ABL', 3.3947896540225138),
#   ('BKC', 15.395529820411069),
#   ('DRG', 44.59182495321799),
#   ('IAN', 41.62360254193453),
#   ('KVL', 3.757454046184266),
#   ('OME', 48.14510938952077),
#   ('ORV', 39.05640702808821),
#   ('SHG', 15.9895268578373),
#   ('WLK', 14.414167088282756),
#   ('WTK', 15.406703151996066)],
#  'PIZ': [('BRW', 24.25469247535452)],
#  'RBY': [('FAI', 7.247249198494706),
#   ('GAL', 5.720277940953299),
#   ('FAI', 14.619096062036668)],
#  'RSH': [('ANI', 6.96646350882195),
#   ('BET', 7.037193084556447),
#   ('KLG', 8.782997673991932),
#   ('ANI', 13.153664642202106)],
#  'SCC': [('BTI', 20.84455188336272),
#   ('FAI', 12.81766196610032),
#   ('NUI', 14.471568525254094)],
#  'SCM': [('BET', 20.617152570392573)],
#  'SHG': [('OBU', 20.19593286402768), ('OBU', 15.456053575575243)],
#  'SHH': [('OME', 28.446944786988954),
#   ('WAA', 33.10278963683009),
#   ('OME', 20.80009741877745)],
#  'SHX': [('ANI', 6.3448391265221), ('ANI', 15.797145132659704)],
#  'SKK': [('KKA', 8.060605802050231),
#   ('OME', 8.954198183131552),
#   ('UNK', 7.687116310191282),
#   ('KKA', 47.91518401169861),
#   ('OME', 41.01785675907632),
#   ('UNK', 44.89446620728744)],
#  'SLQ': [('ANI', 17.81562572998514)],
#  'SMK': [('UNK', 2.217211292643135), ('UNK', 3.757454046184266)],
#  'SVA': [('GAM', 1.305483796993455),
#   ('OME', 0.6567975209882793),
#   ('GAM', 12.582660599715012),
#   ('OME', 14.251070870245591)],
#  'TLA': [('KTS', 1.972570744318628),
#   ('OME', 22.225259534999797),
#   ('KTS', 5.68186656837893)],
#  'TOG': [('KWN', 2.606975817488014)],
#  'UNK': [('ANC', 14.382951360828088),
#   ('SKK', 2.3265720572304907),
#   ('SMK', 3.3544147247389464),
#   ('OME', 5.968140994507764),
#   ('SKK', 16.455839610023126),
#   ('SMK', 16.028444972534245)],
#  'VAK': [('HPB', 16.010783125223476), ('SCM', 10.908892985941916)],
#  'VDZ': [('ANC', 9.53371666651644)],
#  'WAA': [('KTS', 3.3223648480642662),
#   ('OME', 1.5993092948561396),
#   ('OME', 17.330598208876285),
#   ('SHH', 14.738109628037394)],
#  'WLK': [('OTZ', 6.269176123402019), ('OTZ', 14.345601451840643)],
#  'WMO': [('GLV', 9.045356029325724),
#   ('OME', 21.180330909226207),
#   ('GLV', 14.414167088282756),
#   ('OME', 16.747374664450433)],
#  'WTK': [('KVL', 12.63158992718594),
#   ('KVL', 16.575870938880406),
#   ('OTZ', 9.91386033993688)],
#  'AKK': [('ADQ', 15.788559597174665)],
#  'LUR': [('OTZ', 14.189201524932272)],
#  'TNC': [('WAA', 9.311765087102508)],
#  'AET': [('BTT', 25.726089483271625),
#   ('FAI', 23.038905629250458),
#   ('HUS', 5.072103111719381)],
#  'ARC': [('VEE', 12.119938442244209)],
#  'HUS': [('FAI', 15.63722394646057)],
#  'VEE': [('ARC', 3.239303023772358), ('FYU', 17.509534881876228)],
#  'AZO': [('ATL', 5.907453890382596), ('ORD', 14.382951360828088)],
#  'CHA': [('ATL', 9.30960808015032),
#   ('CLT', 5.91606740570836),
#   ('DCA', 20.057100500947683),
#   ('DFW', 8.642776730529853),
#   ('ORD', 7.342614104943727),
#   ('ATL', 10.768045283190071)],
#  'CRW': [('ATL', 16.454105527660683), ('ATL', 7.560540090953043)],
#  'CVG': [('ATL', 2.216834470605168),
#   ('CLT', 27.987411433499723),
#   ('DCA', 31.64310190517822),
#   ('DFW', 13.916418629723232),
#   ('JFK', 8.354245296585688),
#   ('MIA', 7.392870896469949),
#   ('ORD', 14.82957276420213),
#   ('PHL', 7.100959221610026),
#   ('ATL', 16.010783125223476)],
#  'DTW': [('MSY', 5.2893526235295),
#   ('CLT', 20.137347313738392),
#   ('DCA', 18.109659926102957),
#   ('DFW', 27.54933653454703),
#   ('LGA', 20.5915501364026),
#   ('MIA', 15.387352856243073),
#   ('ORD', 27.83045601349457),
#   ('PHL', 14.177042966157464),
#   ('PHX', 14.869979288888278),
#   ('ATL', 22.84127525773932),
#   ('MSY', 6.499208553011326)],
#  'EVV': [('ATL', 2.270029715233695),
#   ('DFW', 11.076039976787364),
#   ('ORD', 16.132802429476875),
#   ('ATL', 16.178876256588925)],
#  'FWA': [('ATL', 7.0041442387151145),
#   ('DFW', 12.826712392990444),
#   ('ORD', 20.5915501364026),
#   ('ATL', 5.828089288990091)],
#  'GFK': [('TVF', 7.404133013814385)],
#  'GSO': [('ATL', 9.713565182393804),
#   ('CLT', 14.702576591264627),
#   ('DCA', 7.560540090953043),
#   ('DFW', 10.48959270322128),
#   ('LGA', 24.14918728682955),
#   ('MIA', 10.80059846492992),
#   ('PHL', 11.049960289822964),
#   ('ATL', 7.581740517812658)],
#  'GSP': [('ATL', 8.312139883852563),
#   ('CLT', 25.35564181392796),
#   ('DCA', 22.170200890109378),
#   ('DFW', 11.387603626053384),
#   ('PHL', 21.301049358772666),
#   ('ATL', 12.027850718528242)],
#  'JFK': [('MSY', 6.742464406784982),
#   ('AUS', 17.494968783346263),
#   ('BNA', 21.05075328096357),
#   ('BOS', 13.306728410254635),
#   ('BWI', 15.236741136608996),
#   ('CLE', 10.45729976367291),
#   ('CLT', 15.650828765111372),
#   ('CMH', 11.906028184011891),
#   ('CVG', 13.637202329579436),
#   ('DCA', 15.63456277038391),
#   ('DFW', 19.111425181736884),
#   ('IND', 13.500708322531027),
#   ('LAS', 14.953015113204025),
#   ('LAX', 10.929922511570789),
#   ('MCO', 13.75570743141614),
#   ('MIA', 14.482176678013715),
#   ('ORD', 16.84745901007964),
#   ('ORF', 15.657344875030152),
#   ('PHX', 9.798102577143505),
#   ('PIT', 8.640573539768164),
#   ('RDU', 21.892568172047746),
#   ('SAN', 16.926281732463597),
#   ('SEA', 29.37892302935833),
#   ('SFO', 15.408466741439756),
#   ('TPA', 17.107526381433626),
#   ('ATL', 33.760677105236525),
#   ('MSY', 28.131549391894996)],
#  'LAN': [('ATL', 17.12413712131326)],
#  'LEX': [('ATL', 3.856813237753925),
#   ('CLT', 1.221712486613395),
#   ('DFW', 45.2456799221936),
#   ('ORD', 41.62360254193453),
#   ('ATL', 5.91606740570836)],
#  'LGA': [('MSY', 6.900630646979721),
#   ('BNA', 41.48152030908404),
#   ('BOS', 40.197207769709024),
#   ('CHO', 1.5620346132917626),
#   ('CLT', 3.1021188077177047),
#   ('CMH', 1.1077108080434162),
#   ('DAY', 0.8424798669239778),
#   ('DCA', 39.2887559772566),
#   ('DFW', 38.12162538392548),
#   ('DTW', 1.550020033026388),
#   ('GSO', 1.815404327293936),
#   ('ILM', 1.221712486613395),
#   ('LIT', 40.197207769709024),
#   ('MIA', 3.1021188077177047),
#   ('ORD', 38.12162538392548),
#   ('ORF', 43.2338536343312),
#   ('PBI', 38.228022352193214),
#   ('PHL', 42.85811039791622),
#   ('PIT', 47.48173824813617),
#   ('RDU', 42.30124495239022),
#   ('RIC', 44.17101199268922),
#   ('ROA', 43.2338536343312),
#   ('SDF', 39.10612149173027),
#   ('STL', 7.385115552668447),
#   ('TYS', 38.228022352193214),
#   ('XNA', 40.272705191729656),
#   ('ATL', 7.342614104943727)],
#  'MBS': [('ATL', 11.836064047340416)],
#  'MDT': [('ATL', 9.70278995679412),
#   ('BOS', 8.848489579860622),
#   ('CLT', 8.192785813957984),
#   ('ORD', 39.99739349882323),
#   ('PHL', 8.670773444280305),
#   ('ATL', 15.20215723986006)],
#  'MEM': [('MSY', 1.3577401211635285),
#   ('CLT', 17.30694945561328),
#   ('DCA', 6.069434382213256),
#   ('DFW', 8.092874563919578),
#   ('MIA', 5.78219410924223),
#   ('ORD', 11.642662915158184),
#   ('ATL', 7.008927674186319)],
#  'MSP': [('ATL', 32.384502234197754),
#   ('MSY', 36.01688352441865),
#   ('CLT', 3.561522085053865),
#   ('DCA', 8.290128561476921),
#   ('DFW', 4.722427882252196),
#   ('MIA', 40.32049198046721),
#   ('ORD', 44.17101199268922),
#   ('PHL', 12.28692083208134),
#   ('PHX', 38.15528648661141),
#   ('ATL', 3.4042953248904344),
#   ('LAX', 10.681483837855804),
#   ('MSY', 17.788304365634154),
#   ('SEA', 10.52725876591015),
#   ('SFO', 6.36056483299381)],
#  'MSY': [('DTW', 4.359690246648972),
#   ('JFK', 9.588819072122622),
#   ('LGA', 11.605517757934944),
#   ('MEM', 1.5070135512106506),
#   ('MSP', 11.728467008499036),
#   ('AUS', 39.10612149173027),
#   ('CLT', 9.83022340785284),
#   ('DCA', 9.659994651855486),
#   ('DFW', 9.472556246191688),
#   ('MIA', 1.5259062673976629),
#   ('ORD', 37.68553890277754),
#   ('PHL', 28.46302131504356),
#   ('DEN', 3.902747731582662),
#   ('EWR', 8.71243051130358),
#   ('IAD', 2.074794952733013),
#   ('IAH', 9.175507942171864),
#   ('ORD', 1.59514020585952),
#   ('ATL', 9.641347220673696),
#   ('DTW', 18.37916077072209),
#   ('JFK', 14.963232981681776),
#   ('MSP', 13.4968284044518)],
#  'ROA': [('ATL', 13.933795119728288),
#   ('CLT', 8.002397572983067),
#   ('LGA', 13.036657486490329),
#   ('PHL', 12.99356088791234),
#   ('ATL', 23.41498150222051)],
#  'SYR': [('ATL', 6.892321921137705),
#   ('BOS', 12.451490256792257),
#   ('CLT', 25.739353639979043),
#   ('DCA', 13.317439182408112),
#   ('ORD', 3.5780762989812107),
#   ('PHL', 3.913426652108877),
#   ('ATL', 10.681483837855804)],
#  'TVF': [('GFK', 4.41961939104867)],
#  'TYS': [('ATL', 9.76099168546909),
#   ('CLT', 24.02378468661186),
#   ('DCA', 21.73397684761978),
#   ('DFW', 13.796175986824991),
#   ('LGA', 4.307564785862877),
#   ('ORD', 15.211462093040064),
#   ('PHL', 48.67617182727086),
#   ('ATL', 34.461664186756195)],
#  'XNA': [('ATL', 11.939443109185056),
#   ('CLT', 44.25905407017086),
#   ('DFW', 16.31749179447751),
#   ('LAX', 3.099094625242212),
#   ('LGA', 15.221268224876384),
#   ('ORD', 22.179477636346235),
#   ('ATL', 11.844882805798012)],
#  'ACK': [('BOS', 16.702419713294248),
#   ('EWB', 4.602236311054016),
#   ('HYA', 7.194766433986054),
#   ('MVY', 5.786821960435575)],
#  'ALB': [('BOS', 6.055552515192334),
#   ('MSS', 10.223116048162378),
#   ('OGS', 14.03486517611845),
#   ('CLT', 2.088299763638072),
#   ('DCA', 17.844164774306208),
#   ('PHL', 13.983856098306862),
#   ('ATL', 4.24969601951998)],
#  'AUG': [('BOS', 9.611893257176774)],
#  'BHB': [('BOS', 12.573610390267602)],
#  'BIL': [('GDV', 4.55740024216886),
#   ('GGW', 8.912515338420958),
#   ('HVR', 15.86723900239779),
#   ('OLF', 39.38956602950423),
#   ('SDY', 8.443188202416392)],
#  'BOS': [('ACK', 29.972827171825607),
#   ('ALB', 6.526194538903667),
#   ('AUG', 3.563565724368898),
#   ('BHB', 3.6554947610601785),
#   ('HYA', 11.942640514692828),
#   ('LEB', 13.122662528176887),
#   ('MVY', 7.808784757629296),
#   ('PVC', 7.652662764588533),
#   ('RKD', 5.94076134240232),
#   ('RUT', 5.752869169824986),
#   ('SLK', 15.757456979443509),
#   ('BUF', 41.03054232773784),
#   ('CLT', 23.838372896586947),
#   ('DCA', 35.34652289668166),
#   ('DFW', 13.708348513500177),
#   ('JFK', 12.64258196624464),
#   ('LAX', 7.867989994439234),
#   ('LGA', 10.536990980640514),
#   ('MDT', 12.986508474724928),
#   ('MIA', 7.125302045955035),
#   ('ORD', 5.518198283510031),
#   ('PDX', 22.87576892434719),
#   ('PHL', 5.914458809010402),
#   ('PHX', 5.828089288990091),
#   ('PIT', 6.794460614572354),
#   ('RIC', 9.46349706808389),
#   ('ROC', 6.544163106245748),
#   ('SAN', 6.277730362489653),
#   ('SEA', 5.178941798982398),
#   ('SYR', 36.879473328005886),
#   ('ATL', 12.745544260327746)],
#  'CGI': [('STL', 35.13919740811786)],
#  'EWB': [('ACK', 5.670957186906906),
#   ('HPN', 4.688518874681618),
#   ('MVY', 39.3059860632044)],
#  'GDV': [('BIL', 39.29102300733915)],
#  'GGW': [('BIL', 28.65999391250372)],
#  'HPN': [('HYA', 7.824954351973991),
#   ('LEB', 9.27568640628469),
#   ('MVY', 7.30262361722145),
#   ('CLT', 11.164894137958816),
#   ('DCA', 12.765809637489555),
#   ('ORD', 11.419825961815592),
#   ('PHL', 10.306434033962764),
#   ('ATL', 6.269176123402019)],
#  'HVR': [('BIL', 14.260504953939613)],
#  'HYA': [('ACK', 13.902764523972408), ('BOS', 3.3709638138185785)],
#  'IRK': [('STL', 6.433371099228165)],
#  'LEB': [('BOS', 12.455834137160242), ('HPN', 3.5532070943450065)],
#  'MSS': [('ALB', 6.462012873337382)],
#  'MVY': [('ACK', 22.026009284862045),
#   ('BOS', 3.1821612702538213),
#   ('EWB', 5.1295237222322125),
#   ('HPN', 11.718917068580108)],
#  'MWA': [('STL', 5.385101617849605)],
#  'OGS': [('ALB', 7.523572980972751)],
#  'OLF': [('BIL', 12.451490256792257)],
#  'OWB': [('STL', 10.626986576481558)],
#  'PVC': [('BOS', 9.30960808015032)],
#  'RKD': [('BOS', 19.508268579811983)],
#  'RUT': [('BOS', 37.80941726922036)],
#  'SDY': [('BIL', 9.464575128711772)],
#  'SLK': [('BOS', 13.739284324348166)],
#  'TBN': [('STL', 8.925540219604601)],
#  'UIN': [('STL', 4.474489143249451)],
#  'ABE': [('CLT', 7.950026246644838),
#   ('PHL', 9.930508030475137),
#   ('ATL', 38.73276705254717)],
#  'ABI': [('DFW', 8.756532077639909)],
#  'ABQ': [('DFW', 15.174436873124751),
#   ('LAX', 11.494523636233438),
#   ('ORD', 13.511106914125028),
#   ('PHX', 13.026634982149329),
#   ('ATL', 14.698414568971303)],
#  'ACT': [('DFW', 14.522855113812234)],
#  'AEX': [('DFW', 12.208331636348223), ('ATL', 10.28582317723222)],
#  'AGS': [('CLT', 5.195667938056673),
#   ('DCA', 8.60605784484498),
#   ('ATL', 13.160654938073048)],
#  'ALO': [('ORD', 17.160267473138116)],
#  'AMA': [('DFW', 5.402877302923882)],
#  'ART': [('ORD', 8.688765335780523), ('PHL', 11.561588625762608)],
#  'AUS': [('CLT', 38.15528648661141),
#   ('DFW', 7.838286821396947),
#   ('JFK', 5.969909292063253),
#   ('LAX', 13.681884508816948),
#   ('MSY', 8.856172711793283),
#   ('ORD', 3.9660298734982784),
#   ('PHL', 16.455839610023126),
#   ('PHX', 15.255149235290936),
#   ('ATL', 8.762743788219026)],
#  'AVL': [('CLT', 25.67896582412516), ('ATL', 11.50823191106478)],
#  'AVP': [('CLT', 25.29596131422887), ('PHL', 25.386700112106144)],
#  'BDL': [('CLT', 7.380076083944043),
#   ('DCA', 10.768045283190071),
#   ('DFW', 9.38311795449605),
#   ('LAX', 5.762506775086129),
#   ('MIA', 7.785406252217155),
#   ('ORD', 16.255804263671784),
#   ('PHL', 9.14260361749305),
#   ('PIT', 12.12899707464254),
#   ('ATL', 30.82090572746091)],
#  'BFL': [('PHX', 16.010783125223476)],
#  'BGM': [('PHL', 10.536990980640514)],
#  'BGR': [('DCA', 16.757181731620147), ('PHL', 4.293677465617154)],
#  'BHM': [('CLT', 14.738109628037394),
#   ('DCA', 9.09378489488694),
#   ('DFW', 3.717123396119589),
#   ('MIA', 30.2249178680638),
#   ('PHL', 4.580720690773743),
#   ('ATL', 27.584643009673)],
#  'BMI': [('DFW', 5.643493643010762),
#   ('ORD', 5.828089288990091),
#   ('ATL', 21.180330909226207)],
#  'BNA': [('CLT', 6.277730362489653),
#   ('DCA', 7.586017890931133),
#   ('DFW', 28.013107848948493),
#   ('JFK', 7.342614104943727),
#   ('LAX', 13.558187907981806),
#   ('LGA', 8.026456699197116),
#   ('MIA', 9.641347220673696),
#   ('ORD', 3.918557296057616),
#   ('PHL', 38.60798254867175),
#   ('ATL', 12.63158992718594)],
#  'BOI': [('PHX', 4.069327024000319)],
#  'BPT': [('DFW', 7.581740517812658)],
#  'BRO': [('DFW', 7.308063014938933)],
#  'BTR': [('CLT', 5.037806540872869),
#   ('DFW', 4.995681849820553),
#   ('ATL', 9.037407550588908)],
#  'BTV': [('DCA', 5.42613944406896), ('PHL', 6.79555589781636)],
#  'BUF': [('BOS', 2.653860689894288),
#   ('CLT', 3.687349338369364),
#   ('DCA', 29.34764944762829),
#   ('ORD', 25.96545435790401),
#   ('PHL', 17.084089004342196),
#   ('ATL', 27.584643009673)],
#  'BUR': [('PDX', 8.765989049025281),
#   ('PHX', 6.269176123402019),
#   ('SEA', 7.586017890931133)],
#  'BWI': [('CLT', 12.04550617653761),
#   ('DFW', 9.045356029325724),
#   ('JFK', 11.605412487557343),
#   ('MIA', 5.195667938056673),
#   ('ORD', 5.509447051173828),
#   ('PHL', 21.180330909226207),
#   ('PHX', 18.378774663823343),
#   ('ATL', 6.069434382213256)],
#  'CAE': [('CLT', 18.37916077072209),
#   ('DCA', 11.140466742024588),
#   ('DFW', 14.956173808315024),
#   ('PHL', 9.97506140705581),
#   ('ATL', 32.77434669177931)],
#  'CAK': [('CLT', 26.0110337069612),
#   ('DCA', 17.02966268705205),
#   ('PHL', 17.057779644635726),
#   ('ATL', 3.561522085053865)],
#  'CHO': [('CLT', 4.41961939104867),
#   ('LGA', 12.218035095802367),
#   ('ORD', 32.16435966817598),
#   ('PHL', 8.22850851326473),
#   ('ATL', 7.523597892838381)],
#  'CHS': [('CLT', 13.317439182408112),
#   ('DCA', 13.627644726007103),
#   ('DFW', 19.321914818749804),
#   ('MIA', 3.505817528306982),
#   ('PHL', 8.688765335780523),
#   ('ATL', 28.473835247851746)],
#  'CID': [('DFW', 17.99561732404454),
#   ('ORD', 13.558187907981806),
#   ('ATL', 31.804734855909576)],
#  'CLE': [('CLT', 15.542418022601243),
#   ('DFW', 18.56663954406416),
#   ('JFK', 10.839270644477454),
#   ('MIA', 32.69876972892605),
#   ('ORD', 43.77261444082002),
#   ('PHL', 3.0475916861890537),
#   ('ATL', 7.099674387153757)],
#  'CLL': [('DFW', 8.026456699197116)],
#  'CLT': [('ABE', 15.03868936084126),
#   ('AGS', 15.019820725376414),
#   ('ALB', 6.369430942923293),
#   ('ATL', 11.561588625762608),
#   ('AUS', 20.90874146930464),
#   ('AVL', 15.58179263944329),
#   ('AVP', 15.379352735171704),
#   ('BDL', 2.907616188220052),
#   ('BHM', 3.5671970914519804),
#   ('BNA', 13.878826071536706),
#   ('BOS', 14.075836767824232),
#   ('BTR', 4.161515822469824),
#   ('BUF', 24.82363689410765),
#   ('BWI', 20.888884660168003),
#   ('CAE', 5.931077030329258),
#   ('CAK', 9.668723278515602),
#   ('CHA', 14.28433858667846),
#   ('CHO', 5.0329425652502735),
#   ('CHS', 6.198937855886535),
#   ('CLE', 17.15670222963794),
#   ('CMH', 26.745623246694542),
#   ('CRW', 17.62971008423518),
#   ('CVG', 22.9458186816326),
#   ('DAB', 6.581255693545122),
#   ('DAY', 4.161515822469824),
#   ('DCA', 7.302769755151259),
#   ('DEN', 27.232643647227416),
#   ('DFW', 10.681483837855804),
#   ('DSM', 12.087139894961211),
#   ('DTW', 4.837849596859439),
#   ('EWN', 6.36056483299381),
#   ('EWR', 9.641347220673696),
#   ('FAY', 18.37916077072209),
#   ('FLL', 8.429949237393128),
#   ('FLO', 12.339811986156215),
#   ('GNV', 14.8424205962641),
#   ('GPT', 45.33037754683284),
#   ('GSO', 5.846172225178702),
#   ('GSP', 9.587851108545223),
#   ('HHH', 4.169489935258799),
#   ('HPN', 10.02802768762255),
#   ('HSV', 30.82090572746091),
#   ('HTS', 18.44625082310705),
#   ('IAD', 3.717123396119589),
#   ('IAH', 38.60798254867175),
#   ('ILM', 11.140466742024588),
#   ('IND', 20.888884660168003),
#   ('JAN', 29.085909719198128),
#   ('JAX', 3.894977280280192),
#   ('JFK', 27.987411433499723),
#   ('LAS', 28.10718724266191),
#   ('LAX', 7.257016819028928),
#   ('LEX', 4.10607620366161),
#   ('LGA', 44.095389901319805),
#   ('LIT', 3.9182288349222056),
#   ('LYH', 17.920688288106817),
#   ('MCI', 5.678236189715399),
#   ('MCO', 6.949859704884861),
#   ('MDT', 3.6273643214424416),
#   ('MEM', 33.61057112676771),
#   ('MGM', 33.98127251293947),
#   ('MHT', 14.956173808315024),
#   ('MIA', 23.524884933810394),
#   ('MKE', 3.894977280280192),
#   ('MLB', 31.64310190517822),
#   ('MOB', 31.81241961922653),
#   ('MSP', 5.368268260754908),
#   ('MSY', 49.06777034408019),
#   ('MYR', 5.720611018920805),
#   ('OAJ', 8.523960300843763),
#   ('OMA', 13.546282752353134),
#   ('ORD', 12.743837296171836),
#   ('ORF', 7.570877260869812),
#   ('PBI', 13.916418629723232),
#   ('PDX', 16.178876256588925),
#   ('PGV', 4.995681849820553),
#   ('PHF', 4.426416885523581),
#   ('PHL', 5.42613944406896),
#   ('PHX', 11.740673784565452),
#   ('PIT', 18.046014939656278),
#   ('PNS', 9.97506140705581),
#   ('PVD', 20.68981221431304),
#   ('PWM', 24.291714980847036),
#   ('RDU', 17.257147024776916),
#   ('RIC', 7.392870896469949),
#   ('ROA', 7.73273263363187),
#   ('ROC', 5.780300529846087),
#   ('RSW', 10.31615844788006),
#   ('SAN', 28.584979498765968),
#   ('SAT', 19.481268370724703),
#   ('SAV', 28.77385781085028),
#   ('SBY', 27.71198772293528),
#   ('SDF', 4.378437857709773),
#   ('SEA', 16.630071365727506),
#   ('SFO', 16.1675739141448),
#   ('SLC', 7.483011055710265),
#   ('SMF', 9.38311795449605),
#   ('SRQ', 17.330598208876285),
#   ('STL', 14.738109628037394),
#   ('SYR', 6.794460614572354),
#   ('TLH', 26.0110337069612),
#   ('TPA', 14.022725059414066),
#   ('TRI', 12.339811986156215),
#   ('TYS', 14.8424205962641),
#   ('VPS', 14.82957276420213),
#   ('XNA', 10.90233156856237),
#   ('ATL', 12.035378092711918)],
#  'CMH': [('CLT', 12.951842224521686),
#   ('DCA', 31.10825312833504),
#   ('DFW', 12.110007056278404),
#   ('JFK', 16.575870938880406),
#   ('LAX', 7.863439159800652),
#   ('LGA', 17.19629905868245),
#   ('MIA', 10.703428454729831),
#   ('ORD', 13.732798378939986),
#   ('PHL', 20.02690945363398),
#   ('PHX', 13.983856098306862),
#   ('ATL', 30.69964662408568)],
#  'CMI': [('DFW', 8.801254034868638), ('ORD', 15.255149235290936)],
#  'COS': [('DFW', 5.762506775086129)],
#  'COU': [('DFW', 16.757181731620147), ('ORD', 9.09378489488694)],
#  'CRP': [('DFW', 5.914458809010402)],
#  'CWA': [('ORD', 16.356940778265514)],
#  'DAB': [('CLT', 8.155995473812583), ('ATL', 16.757181731620147)],
#  'DAY': [('CLT', 30.83328552765534),
#   ('DCA', 12.544163160297956),
#   ('DFW', 35.05247654516415),
#   ('LGA', 12.656878690933503),
#   ('ORD', 25.65694787774452),
#   ('PHL', 7.630112545023476),
#   ('ATL', 4.293677465617154)],
#  'DBQ': [('ORD', 16.332088025857697)],
#  'DCA': [('AGS', 10.736790995808285),
#   ('ALB', 10.167746160898696),
#   ('BDL', 16.38666530269439),
#   ('BGR', 30.79802213575272),
#   ('BHM', 16.278251414320422),
#   ('BNA', 4.136366955920336),
#   ('BOS', 35.01753616896737),
#   ('BTV', 34.8724546389367),
#   ('BUF', 34.461664186756195),
#   ('CAE', 24.246125268515293),
#   ('CAK', 33.979444716619874),
#   ('CHA', 4.00961582116209),
#   ('CHS', 14.763804995803136),
#   ('CLT', 9.869692891182012),
#   ('CMH', 25.12405327507699),
#   ('CRW', 13.935396482470958),
#   ('CVG', 7.565774973687533),
#   ('DAY', 25.19667798488259),
#   ('DFW', 10.90233156856237),
#   ('DSM', 7.100959221610026),
#   ('DTW', 10.263855141904743),
#   ('FAY', 6.441786578123432),
#   ('FLL', 16.356940778265514),
#   ('GSO', 21.873143825212438),
#   ('GSP', 18.624429342333727),
#   ('HHH', 9.93558808923862),
#   ('HPN', 16.901450166956508),
#   ('HSV', 11.844882805798012),
#   ('ILM', 11.605412487557343),
#   ('IND', 17.057779644635726),
#   ('ISP', 18.56663954406416),
#   ('JAN', 28.10718724266191),
#   ('JAX', 31.81241961922653),
#   ('JFK', 7.73273263363187),
#   ('LAS', 15.942491562889288),
#   ('LAX', 5.665795115842085),
#   ('LGA', 13.16727650229993),
#   ('LIT', 25.923886968855356),
#   ('MCI', 17.522491264034258),
#   ('MCO', 34.705610974414824),
#   ('MEM', 34.88767514809936),
#   ('MHT', 4.8728987860968696),
#   ('MIA', 15.90339065229735),
#   ('MSP', 14.275361956162593),
#   ('MSY', 12.5033312304057),
#   ('MYR', 5.780300529846087),
#   ('OAJ', 6.284865956643601),
#   ('OMA', 5.665795115842085),
#   ('ORD', 29.870205677345936),
#   ('ORF', 22.002759729720054),
#   ('PBI', 6.7638846880976),
#   ('PDX', 6.874692229350543),
#   ('PHL', 7.414623362301863),
#   ('PHX', 16.40089113852978),
#   ('PIT', 7.184827011467771),
#   ('PNS', 17.469268115914492),
#   ('PVD', 19.321914818749804),
#   ('PWM', 10.088960483627035),
#   ('RDU', 10.839270644477454),
#   ('ROC', 5.0329425652502735),
#   ('RSW', 25.62730998483296),
#   ('SAN', 10.31615844788006),
#   ('SAV', 9.084645956284064),
#   ('SDF', 12.055845715318226),
#   ('SRQ', 13.16727650229993),
#   ('STL', 27.07104130826413),
#   ('SYR', 8.756014945151993),
#   ('TLH', 7.984012714903168),
#   ('TPA', 39.39494391062327),
#   ('TYS', 17.67805876035554),
#   ('VPS', 7.257016819028928),
#   ('ATL', 16.92760584750399)],
#  'DEN': [('CLT', 13.289180937269686),
#   ('DFW', 21.27137290327675),
#   ('LAX', 2.653860689894288),
#   ('MIA', 6.198937855886535),
#   ('ORD', 17.564740300402743),
#   ('PHL', 11.741299252630837),
#   ('PHX', 7.971388160083139),
#   ('SEA', 8.155995473812583),
#   ('ATL', 7.323196517887812),
#   ('MSY', 2.4507777182759622),
#   ('ATL', 14.738109628037394)],
#  'DFW': [('ABI', 22.955470912425653),
#   ('ABQ', 6.086138646342636),
#   ('ACT', 14.1717802039079),
#   ('AEX', 3.1771960536789416),
#   ('AMA', 2.3281377152178635),
#   ('ATL', 9.886819270692886),
#   ('AUS', 12.544163160297956),
#   ('BDL', 8.192785813957984),
#   ('BHM', 18.817658674902876),
#   ('BMI', 7.8764286710531),
#   ('BNA', 26.996577546342746),
#   ('BOS', 14.647338713779588),
#   ('BPT', 22.30296411108037),
#   ('BRO', 12.951842224521686),
#   ('BTR', 12.656878690933503),
#   ('BWI', 37.33017685458013),
#   ('CAE', 27.584643009673),
#   ('CHA', 17.15670222963794),
#   ('CHS', 4.10607620366161),
#   ('CID', 11.07258017784204),
#   ('CLE', 5.623468453890182),
#   ('CLL', 16.118089272227387),
#   ('CLT', 37.33017685458013),
#   ('CMH', 5.225196399708177),
#   ('CMI', 10.666696677528243),
#   ('COS', 5.860968700551471),
#   ('COU', 8.036665095459142),
#   ('CRP', 3.799807359000176),
#   ('CRW', 12.110007056278404),
#   ('CVG', 5.837779829220413),
#   ('DAY', 16.575870938880406),
#   ('DCA', 16.332088025857697),
#   ('DEN', 46.64588178163907),
#   ('DRO', 40.568583578475135),
#   ('DSM', 7.773341485665493),
#   ('DTW', 6.069434382213256),
#   ('ELP', 7.894563056572327),
#   ('EVV', 3.920011272177221),
#   ('EWR', 7.863439159800652),
#   ('FAR', 43.622273619874285),
#   ('FAT', 8.744913476542918),
#   ('FLL', 8.092874563919578),
#   ('FSD', 32.09716809456604),
#   ('FSM', 15.132953096470526),
#   ('FWA', 10.167746160898696),
#   ('GCK', 7.58692836073689),
#   ('GGG', 13.188490004551632),
#   ('GJT', 32.77434669177931),
#   ('GPT', 41.03054232773784),
#   ('GRI', 14.4043469708785),
#   ('GRK', 22.127661247292775),
#   ('GRR', 3.9182288349222056),
#   ('GSO', 5.225196399708177),
#   ('GSP', 7.240030251646264),
#   ('HNL', 31.921099095894675),
#   ('HOU', 6.62463030065719),
#   ('HSV', 14.628875597969092),
#   ('IAD', 23.838372896586947),
#   ('IAH', 3.687349338369364),
#   ('ICT', 3.192857115193989),
#   ('IND', 17.920688288106817),
#   ('JAN', 20.41982145498859),
#   ('JAX', 17.19629905868245),
#   ('JFK', 16.278251414320422),
#   ('JLN', 14.092757020492703),
#   ('LAS', 12.268779665455884),
#   ('LAW', 16.01259506907548),
#   ('LAX', 4.722427882252196),
#   ('LBB', 9.122786948158785),
#   ('LCH', 10.703428454729831),
#   ('LEX', 4.136366955920336),
#   ('LFT', 46.38454588847027),
#   ('LGA', 19.19884687265981),
#   ('LIT', 9.728101101614724),
#   ('LRD', 17.39080263879582),
#   ('MAF', 12.2919979691332),
#   ('MCI', 38.15528648661141),
#   ('MCO', 17.84350370561814),
#   ('MEM', 34.8724546389367),
#   ('MFE', 46.179479644354174),
#   ('MGM', 17.436031229187815),
#   ('MHK', 6.897284593574858),
#   ('MIA', 4.9086182696438),
#   ('MKE', 6.62463030065719),
#   ('MLI', 35.34652289668166),
#   ('MLU', 24.246125268515293),
#   ('MOB', 40.59895893291807),
#   ('MSN', 10.692344616731276),
#   ('MSP', 11.65449890560672),
#   ('MSY', 12.2919979691332),
#   ('OGG', 10.92869927782716),
#   ('OKC', 7.410253998793834),
#   ('OMA', 8.782997673991932),
#   ('ONT', 6.249652932754116),
#   ('ORD', 14.573077078791393),
#   ('ORF', 3.6273643214424416),
#   ('PBI', 5.860968700551471),
#   ('PDX', 5.9885461558657465),
#   ('PHL', 7.838286821396947),
#   ('PHX', 4.529440271179327),
#   ('PIA', 13.708348513500177),
#   ('PIT', 7.581740517812658),
#   ('PNS', 14.34623287143172),
#   ('PSP', 8.871692437064358),
#   ('RAP', 24.925264771530085),
#   ('RDU', 28.446944786988954),
#   ('RIC', 4.378437857709773),
#   ('RNO', 4.00961582116209),
#   ('ROW', 4.8728987860968696),
#   ('RSW', 6.7638846880976),
#   ('SAF', 7.971388160083139),
#   ('SAN', 15.17054321224943),
#   ('SAT', 11.933046821645624),
#   ('SAV', 12.268779665455884),
#   ('SDF', 17.160267473138116),
#   ('SEA', 5.969909292063253),
#   ('SFO', 17.08798281382943),
#   ('SGF', 7.002140049060378),
#   ('SHV', 12.64258196624464),
#   ('SJC', 12.986508474724928),
#   ('SJT', 3.505817528306982),
#   ('SLC', 12.854623886646692),
#   ('SMF', 15.916228256030267),
#   ('SNA', 16.630071365727506),
#   ('SPI', 14.763804995803136),
#   ('SPS', 15.90339065229735),
#   ('STL', 7.984012714903168),
#   ('TLH', 43.76542818037044),
#   ('TPA', 29.979960254282148),
#   ('TUL', 17.68480044220344),
# ...
#  'MFR': [('LAX', 38.15528648661141)],
#  'MGM': [('CLT', 9.472556246191688),
#   ('DFW', 37.68553890277754),
#   ('ATL', 12.548906644683626)],
#  'MHK': [('DFW', 37.50562355533041), ('ORD', 33.43991835805748)],
#  'MHT': [('CLT', 6.516486469648934),
#   ('DCA', 7.838286821396947),
#   ('PHL', 12.610253194953325)],
#  'MIA': [('ATL', 3.484294822953755),
#   ('BDL', 3.077690105958881),
#   ('BHM', 10.226719710707505),
#   ('BNA', 11.382019226953146),
#   ('BOS', 2.606975817488014),
#   ('BWI', 14.382951360828088),
#   ('CHS', 16.010783125223476),
#   ('CLE', 3.798089844869328),
#   ('CLT', 15.63722394646057),
#   ('CMH', 10.908892985941916),
#   ('CVG', 1.5993092948561396),
#   ('DCA', 11.003055728652754),
#   ('DEN', 8.191354104924898),
#   ('DFW', 3.825324532487287),
#   ('DTW', 6.544163106245748),
#   ('EWR', 1.2313467895256454),
#   ('EYW', 5.417407271631167),
#   ('GNV', 12.151238411729882),
#   ('GSO', 14.03486517611845),
#   ('IAD', 5.385101617849605),
#   ('IAH', 7.523572980972751),
#   ('IND', 12.451490256792257),
#   ('JAX', 9.464575128711772),
#   ('JFK', 5.710756004407472),
#   ('LAS', 9.35378026325686),
#   ('LAX', 10.08361842551695),
#   ('LGA', 7.381756146471591),
#   ('MCO', 41.48152030908404),
#   ('MEM', 13.043712722796986),
#   ('MSP', 13.610132938051343),
#   ('MSY', 6.55621427421604),
#   ('ORD', 12.745544260327746),
#   ('ORF', 19.619038741916142),
#   ('PHL', 12.28692083208134),
#   ('PHX', 4.021075145568373),
#   ('PIT', 30.82090572746091),
#   ('PNS', 40.22890478405786),
#   ('RDU', 12.743837296171836),
#   ('RIC', 11.740673784565452),
#   ('SAN', 8.801254034868638),
#   ('SDF', 15.975487933157618),
#   ('SEA', 9.93558808923862),
#   ('SFO', 6.703253542503768),
#   ('STL', 27.45937129629189),
#   ('TLH', 14.03486517611845),
#   ('TPA', 19.619038741916142),
#   ('TUL', 28.42564949718601),
#   ('ATL', 11.561588625762608)],
#  'MKE': [('CLT', 9.037407550588908),
#   ('DFW', 8.848489579860622),
#   ('ORD', 8.192785813957984),
#   ('PHL', 39.99739349882323),
#   ('PHX', 8.670773444280305),
#   ('ATL', 10.768045283190071)],
#  'MLB': [('CLT', 11.10309643256348), ('ATL', 2.907616188220052)],
#  'MLI': [('DFW', 27.584643009673),
#   ('ORD', 8.781119847825767),
#   ('ATL', 20.43293503160437)],
#  'MLU': [('DFW', 4.197115872300928), ('ATL', 13.878826071536706)],
#  'MMH': [('LAX', 6.985138981107955)],
#  'MOB': [('CLT', 15.32135208524409),
#   ('DFW', 6.069434382213256),
#   ('ATL', 11.307668322397731)],
#  'MQT': [('ORD', 8.092874563919578)],
#  'MRY': [('LAX', 11.642662915158184), ('PHX', 7.58692836073689)],
#  'MSN': [('DFW', 32.77434669177931),
#   ('ORD', 14.628875597969092),
#   ('ATL', 4.161515822469824)],
#  'MYR': [('CLT', 5.969909292063253),
#   ('DCA', 3.484294822953755),
#   ('PHL', 11.74282250312596),
#   ('ATL', 16.324607563949925)],
#  'OAJ': [('CLT', 8.762743788219026),
#   ('DCA', 9.037407550588908),
#   ('ATL', 19.95363696400816)],
#  'OAK': [('HNL', 19.321914818749804),
#   ('KOA', 8.762743788219026),
#   ('LIH', 15.621091936986428),
#   ('OGG', 5.083404880106152),
#   ('PDX', 19.619038741916142),
#   ('PHX', 19.321914818749804),
#   ('SEA', 15.621091936986428)],
#  'OGG': [('DFW', 5.083404880106152),
#   ('LAX', 19.619038741916142),
#   ('OAK', 9.037407550588908),
#   ('PHX', 3.578867739818959),
#   ('SJC', 0.9058312216740508),
#   ('SMF', 3.578867739818959)],
#  'OKC': [('DFW', 0.8109815815878121),
#   ('LAX', 0.8109815815878121),
#   ('ORD', 1.6524886888314718),
#   ('ATL', 3.1771960536789416)],
#  'OMA': [('CLT', 1.9411912218698075),
#   ('DCA', 0.9058312216740508),
#   ('DFW', 1.6524886888314718),
#   ('ORD', 1.9411912218698075),
#   ('PHX', 1.3354917118705958),
#   ('ATL', 12.077100077737173)],
#  'ONT': [('DFW', 1.3258283341191497),
#   ('PDX', 1.3354917118705958),
#   ('PHX', 0.2183249319021971),
#   ('SEA', 1.2269267811557607)],
#  'ORF': [('CLT', 12.077100077737173),
#   ('DCA', 40.09062209219371),
#   ('DFW', 3.9182288349222056),
#   ('JFK', 21.395564461260182),
#   ('LGA', 36.01688352441865),
#   ('MIA', 39.05640702808821),
#   ('PHL', 23.40372749616778),
#   ('ATL', 35.196645360076445)],
#  'PDX': [('BOS', 14.118297805375784),
#   ('BUR', 11.99856597973701),
#   ('CLT', 15.06935401390566),
#   ('DCA', 17.509534881876228),
#   ('DFW', 12.5033312304057),
#   ('LAX', 12.578091224746398),
#   ('LGB', 15.047630653120049),
#   ('OAK', 23.630637693037368),
#   ('ONT', 27.45937129629189),
#   ('ORD', 6.058072071387044),
#   ('PHL', 7.375507945406745),
#   ('PHX', 7.232992636830698),
#   ('SAN', 11.75575335653785),
#   ('SFO', 5.942250192597125),
#   ('SJC', 5.397195323093564),
#   ('SNA', 18.1266178385189),
#   ('ATL', 28.446944786988954)],
#  'PGV': [('CLT', 7.206857785860821)],
#  'PHF': [('CLT', 25.64096711950718),
#   ('PHL', 7.257016819028928),
#   ('ATL', 5.037806540872869)],
#  'PHL': [('ABE', 34.57927434644417),
#   ('ALB', 13.563934693496495),
#   ('ART', 16.901292022097753),
#   ('ATL', 17.694515116119607),
#   ('AUS', 27.878346288409837),
#   ('AVP', 31.54399921504915),
#   ('BDL', 6.058072071387044),
#   ('BGM', 12.224947030720786),
#   ('BGR', 34.57927434644417),
#   ('BHM', 16.621830902184268),
#   ('BNA', 14.998028254256514),
#   ('BOS', 19.744295573845537),
#   ('BTV', 28.53765512776364),
#   ('BUF', 12.077100077737173),
#   ('BWI', 13.946325554162405),
#   ('CAE', 22.88573960912017),
#   ('CAK', 40.09062209219371),
#   ('CHO', 9.7556363763416),
#   ('CHS', 14.983642793512857),
#   ('CLE', 14.781281538723068),
#   ('CLT', 15.757456979443509),
#   ('CMH', 16.621830902184268),
#   ('CVG', 3.9182288349222056),
#   ('DAY', 13.946325554162405),
#   ('DCA', 13.969129038082558),
#   ('DEN', 15.316931587162516),
#   ('DFW', 14.260504953939613),
#   ('DTW', 14.998028254256514),
#   ('ELM', 28.42564949718601),
#   ('ERI', 28.42564949718601),
#   ('EWR', 38.15528648661141),
#   ('FLL', 12.745544260327746),
#   ('GSO', 9.037407550588908),
#   ('GSP', 5.215913074726584),
#   ('HPN', 10.401275783435072),
#   ('HVN', 5.215913074726584),
#   ('IAH', 4.279148996986804),
#   ('ILM', 10.146466443636983),
#   ('IND', 2.9066682954311776),
#   ('IPT', 4.279148996986804),
#   ('ISP', 2.9066682954311776),
#   ('ITH', 10.401275783435072),
#   ('JAX', 10.146466443636983),
#   ('LAS', 1.4625884486610232),
#   ('LAX', 1.4625884486610232),
#   ('LGA', 12.63158992718594),
#   ('MCI', 7.375507945406745),
#   ('MCO', 12.21403119320778),
#   ('MDT', 9.037407550588908),
#   ('MHT', 12.21403119320778),
#   ('MIA', 11.50823191106478),
#   ('MKE', 9.037407550588908),
#   ('MSP', 41.62360254193453),
#   ('MSY', 19.619038741916142),
#   ('MYR', 44.12518336616964),
#   ('ORD', 19.619038741916142),
#   ('ORF', 9.037407550588908),
#   ('PBI', 14.189201524932272),
#   ('PDX', 12.21403119320778),
#   ('PHF', 44.12518336616964),
#   ('PHX', 31.54399921504915),
#   ('PIT', 4.9086182696438),
#   ('PVD', 22.358802820172272),
#   ('PWM', 8.509773929643032),
#   ('RDU', 17.270927608371842),
#   ('RIC', 12.578091224746398),
#   ('ROA', 19.90031845908217),
#   ('ROC', 8.509773929643032),
#   ('RSW', 8.886884521919626),
#   ('SAN', 23.630637693037368),
#   ('SAT', 27.45937129629189),
#   ('SAV', 20.31263038917273),
#   ('SBY', 6.284865956643601),
#   ('SCE', 22.358802820172272),
#   ('SDF', 17.270927608371842),
#   ('SEA', 19.90031845908217),
#   ('SFO', 8.886884521919626),
#   ('SLC', 27.45937129629189),
#   ('STL', 20.31263038917273),
#   ('SWF', 22.002759729720054),
#   ('SYR', 21.634492684495545),
#   ('TPA', 29.200248070925223),
#   ('TYS', 30.0443030180772),
#   ('ATL', 13.546282752353134)],
#  'PHX': [('ABQ', 4.0208419537073015),
#   ('ANC', 3.652144476426384),
#   ('ATL', 4.0208419537073015),
#   ('AUS', 5.083404880106152),
#   ('BFL', 5.083404880106152),
#   ('BOI', 12.534385530230468),
#   ('BOS', 5.195667938056673),
#   ('BUR', 12.34989639702568),
#   ('BWI', 11.849947112107197),
#   ('CLT', 19.949649711699514),
#   ('CMH', 15.975510317738667),
#   ('DCA', 3.780253315320244),
#   ('DEN', 3.398680629653669),
#   ('DFW', 22.823090204149477),
#   ('DRO', 13.563934693496495),
#   ('DSM', 3.0978537585955603),
#   ('DTW', 0.8366397361529854),
#   ('ELP', 8.158336838787678),
#   ('EWR', 2.088299763638072),
#   ('FAT', 5.2745972416743285),
#   ('FLG', 14.124091795665231),
#   ('FLL', 2.704624949040864),
#   ('GEG', 5.509447051173828),
#   ('GJT', 8.240956196420276),
#   ('HNL', 50.08399063273245),
#   ('IAH', 64.9907386149351),
#   ('IND', 30.90237488655231),
#   ('JFK', 1.6045138744815268),
#   ('KOA', 0.5142783270405209),
#   ('LAS', 2.2869463104843124),
#   ('LAX', 12.6899242546278),
#   ('LGB', 8.191354104924898),
#   ('LIH', 12.451490256792257),
#   ('MCI', 8.762743788219026),
#   ('MCO', 11.50823191106478),
#   ('MIA', 9.037407550588908),
#   ('MKE', 38.15528648661141),
#   ('MRY', 2.360820926955637),
#   ('MSP', 19.393326996036016),
#   ('OAK', 25.739353639979043),
#   ('OGG', 22.02662433981976),
#   ('OMA', 2.33795828288734),
#   ('ONT', 21.07406523671952),
#   ('ORD', 15.304318114283769),
#   ('PDX', 25.796612356492023),
#   ('PHL', 8.45959575970366),
#   ('PIT', 12.198210216533806),
#   ('PSP', 5.63419901720993),
#   ('RNO', 3.233477607972644),
#   ('SAN', 0.7102929961624783),
#   ('SAT', 15.050168573128593),
#   ('SBA', 24.333586590868137),
#   ('SBP', 1.6262176546472835),
#   ('SEA', 3.973045956131679),
#   ('SFO', 3.5823990501999847),
#   ('SJC', 18.9942922787394),
#   ('SLC', 8.494084890798721),
#   ('SMF', 7.094495927216175),
#   ('SNA', 7.948789118077846),
#   ('STL', 3.8465881872220216),
#   ('TPA', 2.2781877957711294),
#   ('TUS', 7.160163190130181),
#   ('YUM', 13.317439182408112),
#   ('ATL', 13.624649440887906)],
#  'PIA': [('DFW', 12.12899707464254),
#   ('ORD', 9.8668712217135),
#   ('ATL', 7.570877260869812)],
#  'PIT': [('BDL', 28.36256629745137),
#   ('BOS', 8.555401388661396),
#   ('CLT', 10.886354995348382),
#   ('DCA', 33.760677105236525),
#   ('DFW', 3.5780762989812107),
#   ('JFK', 7.301045594617539),
#   ('LAX', 27.304073006829647),
#   ('LGA', 48.14510938952077),
#   ('MIA', 16.90399802318908),
#   ('ORD', 51.58850543451696),
#   ('PHL', 4.579517348920945),
#   ('PHX', 4.227575321711403),
#   ('RDU', 3.913426652108877),
#   ('STL', 7.0045495945549705),
#   ('ATL', 13.916418629723232)],
#  'PSP': [('DFW', 6.203200346817566),
#   ('ORD', 14.761427903245316),
#   ('PHX', 10.52039335332216),
#   ('SFO', 6.549359833509841)],
#  'PVD': [('CLT', 12.0122285608829),
#   ('DCA', 2.2369624148203795),
#   ('PHL', 13.119111015513464),
#   ('ATL', 9.97506140705581)],
#  'RAP': [('DFW', 7.160163190130181)],
#  'RDM': [('LAX', 10.886354995348382)],
#  'RDU': [('CLT', 3.472268321707675),
#   ('DCA', 5.643493643010762),
#   ('DFW', 8.703243325960385),
#   ('JFK', 6.263672774611544),
#   ('LAX', 1.756279677921624),
#   ('LGA', 2.80944544591269),
#   ('MIA', 22.87576892434719),
#   ('ORD', 17.412208436287294),
#   ('PHL', 2.960318693469921),
#   ('PIT', 1.805426611780433),
#   ('ATL', 17.257147024776916)],
#  'RIC': [('BOS', 1.98968991620896),
#   ('CLT', 15.432698553263636),
#   ('DFW', 2.4495828455192883),
#   ('LGA', 3.955900635300539),
#   ('MIA', 6.526448286720182),
#   ('ORD', 5.039275069492161),
#   ('PHL', 17.680681236608663),
#   ('ATL', 7.73273263363187)],
#  'RNO': [('DFW', 4.756625934985832),
#   ('LAX', 2.6958354541862954),
#   ('ORD', 33.72628803727941),
#   ('PHX', 37.31341203622098)],
#  'ROC': [('BOS', 6.238712489689291),
#   ('CLT', 11.889718037564048),
#   ('DCA', 14.180108216699804),
#   ('ORD', 6.081480287875863),
#   ('PHL', 14.832597682034017),
#   ('ATL', 16.630071365727506)],
#  'ROW': [('DFW', 31.199315749210783)],
#  'RST': [('ORD', 2.106995539225571)],
#  'SAF': [('DFW', 6.263672774611544), ('LAX', 8.71243051130358)],
#  'SAN': [('BOS', 9.706959907891484),
#   ('CLT', 1.756279677921624),
#   ('DCA', 21.78152388997613),
#   ('DFW', 8.75080067513234),
#   ('JFK', 5.5372381565957),
#   ('LAX', 15.976929840948882),
#   ('MCO', 5.22258843255627),
#   ('MIA', 6.374392350337948),
#   ('ORD', 27.245546516815917),
#   ('PDX', 12.861538326651935),
#   ('PHL', 14.54419328244876),
#   ('PHX', 17.093239819196302),
#   ('SEA', 3.5337859447053632),
#   ('STS', 3.092979967071424),
#   ('ATL', 17.330598208876285)],
#  'SAT': [('CLT', 7.212752158783329),
#   ('DFW', 14.003181697451137),
#   ('ORD', 4.3659916332217525),
#   ('PHL', 3.3074230805317466),
#   ('PHX', 1.301446710459182),
#   ('ATL', 14.738109628037394)],
#  'SAV': [('CLT', 4.213004470084942),
#   ('DCA', 3.236719513264714),
#   ('DFW', 2.80944544591269),
#   ('PHL', 20.453638521889435),
#   ('ATL', 11.70523945767212)],
#  'SBA': [('PHX', 10.081704960791605)],
#  'SBP': [('PHX', 6.8310906505960425)],
#  'SBY': [('CLT', 4.229986745183124), ('PHL', 5.450494900065211)],
#  'SCE': [('PHL', 27.653735155330263)],
#  'SDF': [('CLT', 5.195667938056673),
#   ('DCA', 2.880247236369912),
#   ('DFW', 2.704624949040864),
#   ('LGA', 5.509447051173828),
#   ('MIA', 50.08399063273245),
#   ('ORD', 2.2869463104843124),
#   ('PHL', 21.180330909226207),
#   ('ATL', 11.676391512359764)],
#  'SEA': [('BOS', 18.9942922787394),
#   ('BUR', 7.094495927216175),
#   ('CLT', 7.948789118077846),
#   ('DEN', 18.378774663823343),
#   ('DFW', 12.12899707464254),
#   ('EWR', 33.760677105236525),
#   ('JFK', 14.810592021343489),
#   ('KTN', 28.013107848948493),
#   ('LAX', 8.774232564021899),
#   ('LGB', 13.119111015513464),
#   ('MCI', 21.78152388997613),
#   ('MCO', 6.374392350337948),
#   ('MIA', 1.056267938972154),
#   ('OAK', 3.5337859447053632),
#   ('ONT', 20.021704542663343),
#   ('ORD', 1.301446710459182),
#   ('PHL', 27.653735155330263),
#   ('PHX', 10.334550474491648),
#   ('SAN', 7.183634221472537),
#   ('SFO', 4.103381423998429),
#   ('SJC', 11.136174830855577),
#   ('SMF', 21.448798045555552),
#   ('SNA', 2.255668644715392),
#   ('STL', 8.232981248773404),
#   ('ATL', 3.899420784742761),
#   ('HNL', 15.053206525396693)],
#  'SFO': [('CLT', 30.515606961591686),
#   ('DFW', 10.562432952462212),
#   ('JFK', 28.131549391894996),
#   ('LAX', 4.731787136078307),
#   ('MIA', 4.57000476758387),
#   ('ORD', 15.019820725376414),
#   ('PDX', 3.9242719405641777),
#   ('PHL', 19.38672540215805),
#   ('PHX', 10.145553537191184),
#   ('PSP', 2.6211933474363147),
#   ('SEA', 9.946485604325543),
#   ('ATL', 12.339811986156215),
#   ('HNL', 9.587851108545223)],
#  'SGF': [('DFW', 56.385271220436366),
#   ('ORD', 18.64484008268026),
#   ('ATL', 34.69700329834084)],
#  'SHV': [('DFW', 13.588219666041212), ('ATL', 17.5449364903666)],
#  'SJC': [('DFW', 18.37916077072209),
#   ('HNL', 7.128378943705027),
#   ('KOA', 55.17351768543741),
#   ('LAX', 1.7628616044854513),
#   ('LIH', 11.140466742024588),
#   ('OGG', 14.956173808315024),
#   ('ORD', 6.821942579845102),
#   ('PDX', 30.81400279240109),
#   ('PHX', 57.51756805111732),
#   ('SEA', 13.465162764187182)],
#  'SJT': [('DFW', 9.057252352947572)],
#  'SLC': [('CLT', 15.00117883847086),
#   ('DFW', 6.2996179174938405),
#   ('LAX', 24.44820741340849),
#   ('ORD', 15.801441960409909),
#   ('PHL', 13.282647474224731),
#   ('PHX', 1.582414959441801),
#   ('ATL', 12.951842224521686)],
#  'SMF': [('CLT', 17.052416078437084),
#   ('DFW', 4.721364077221132),
#   ('LAX', 15.09935559772369),
#   ('OGG', 26.51026520005072),
#   ('PHX', 4.474558360030064),
#   ('SEA', 14.4043469708785),
#   ('ATL', 16.575870938880406)],
#  'SNA': [('DFW', 12.047702600953794),
#   ('ORD', 16.111564572814657),
#   ('PDX', 19.012017575352235),
#   ('PHX', 19.19884687265981),
#   ('SEA', 17.84350370561814),
#   ('ATL', 7.863439159800652)],
#  'SPS': [('DFW', 9.277952543774854)],
#  'SRQ': [('CLT', 13.139622190905722),
#   ('DCA', 17.436031229187815),
#   ('ATL', 15.069981926314489)],
#  'STS': [('LAX', 21.395564461260182), ('SAN', 12.88000141131497)],
#  'SUX': [('ORD', 19.51255373937332)],
#  'SWF': [('PHL', 5.775439051474868)],
#  'TOL': [('ORD', 10.081704960791605)],
#  'TRI': [('CLT', 23.72649604837003), ('ATL', 32.09716809456604)],
#  'TUL': [('DFW', 2.911581881066523),
#   ('MIA', 12.670661960810005),
#   ('ORD', 41.242030138174975),
#   ('ATL', 16.38666530269439)],
#  'TUS': [('DFW', 44.751288296436485),
#   ('LAX', 20.592495276100625),
#   ('ORD', 14.190401708238676),
#   ('PHX', 16.787389897107506),
#   ('ATL', 4.136366955920336)],
#  'TVC': [('ORD', 3.533742084017228)],
#  'TXK': [('DFW', 16.107975535461073)],
#  'TYR': [('DFW', 8.475444804966221)],
#  'VPS': [('CLT', 43.75130237247273),
#   ('DCA', 26.74065001671147),
#   ('DFW', 11.082699989149011),
#   ('ATL', 6.441786578123432)],
#  'YUM': [('PHX', 2.6251717156118555)],
#  'ABY': [('ATL', 32.55326701404432)],
#  'ATW': [('ATL', 8.642776730529853)],
#  'BQK': [('ATL', 33.98127251293947)],
#  'CSG': [('ATL', 8.37364030859211)],
#  'DAL': [('ATL', 16.901450166956508)],
#  'DHN': [('ATL', 34.61087882444435)],
#  'ECP': [('ATL', 9.598549137803596)],
#  'GTR': [('ATL', 2.907616188220052)],
#  'MDW': [('ATL', 4.6255037591545385)],
#  'SBN': [('ATL', 12.48741050034197)],
#  'VLD': [('ATL', 10.263855141904743)]}

# %% [markdown]
# ## Depth First Search

# %%
def dfs(graph, start, end, visited=None, path=None):
    if visited is None:
        visited = []
    if path is None:
        path = [start]

    visited.append(start)

    # Se o vértice de destino foi alcançado
    if start == end:
        return path

    # Pegando os vértices adjacentes
    neighbours = [neighbour for neighbour, dist in graph.get(start, [])]
    for neighbour in neighbours:
        if neighbour not in visited:
            new_path = dfs(graph, neighbour, end, visited, path + [neighbour])
            if new_path:  # Se um caminho válido foi encontrado, retorne-o
                return new_path

    return None  # Se nenhum caminho foi encontrado

# %% [markdown]
# O código acima gera uma lista , descrevendo todos os nós intermediários do caminho entre A e B.

# %%
def calcula_distancia(start, path, distance):
    
    for i in path:

        distance += graph[(graph['source'] == start) & (graph['dest'] == i)]['distance'].iloc[0]
        start = i
    
    return distance

# %%
start = "ADQ"
end = "KLN"
dfs_result_dict = dfs(graph_dict, start, end, [], [])
dfs_result_dict
# Out:
# ['KLN']

# %%
distance = calcula_distancia(start, dfs_result_dict, 0)
distance
# Out:
# 2.128521013470194
